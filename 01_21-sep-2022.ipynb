# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_exp = np.linspace(0, 10, 100000)
x_disc = np.random.randint(0, 10, 100000)
x_cont = np.random.normal(0, 10, 100000)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.hist(x_disc, bins=100, density=True)


plt.subplot(1, 2, 2)
plt.hist(x_cont, bins=100, density=True)
plt.show()
